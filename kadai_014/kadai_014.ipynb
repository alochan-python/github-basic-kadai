# %%
#関数外定義
price1 = 100
price2 = 200
tax = 1.1
def total():
    tax = 1.1
    return price1 + price2

print (f"関数外定義{total() * tax}")

#関数内定義
price1 = 100
price2 = 200

def total():
    tax = 1.1
    return ((price1 + price2) * tax)

print (f"関数内定義{total() }")
# Out:
# 関数外定義330.0
# 関数内定義330.0
