# %%
class Human:
  def __init__(self,name,age):
    self.name = name
    self.age = age

  def printinfo(self):
    print(self.name,self.age)

information = Human("侍百郎","100")
information.printinfo()
# Out:
# 侍百郎 100
