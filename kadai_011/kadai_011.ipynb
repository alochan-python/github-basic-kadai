# %%
array = ["水","金","地","火","木","土","天","海","冥"]

print("=======")
print("for文")
for planet in array:
  print(planet)
print("=======")
print("whie文")
index=0
while index < len(array):
  print(array[index])
  index+=1
# Out:
# ...
# for文
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# ...
# whie文
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
