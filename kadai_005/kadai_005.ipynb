# %%
top_side=10
down_side=20
height=5
result=(top_side+down_side)*height/2

print("上辺：10cm")
print("下辺：10cm")
print("高さ：10cm")
print("")
print("公式：台形の面積 =（上辺＋下辺）× 高さ ÷ 2")
print("")
print(f"台形の面積：{result}cm²")
# Out:
# 上辺：10cm
# 下辺：10cm
# 高さ：10cm
#
# 公式：台形の面積 =（上辺＋下辺）× 高さ ÷ 2
#
# 台形の面積：75.0cm²
